# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_excel("data.xlsx")

# %%
import pandas as pd


df = pd.DataFrame(pd.read_excel("data.xlsx"))

df
# Out:
#                                  Testing Information       Unnamed: 1  \
# 0                          240067-1-1-2818574209.xls              NaN
# 1                                2020-10-16 08:34:59              NaN
# 2  C:\Users\shivangi\Desktop\1522\xls\240067-1-1-...              NaN
# 3                            Cycle Mode:Charge First              NaN
# 4                                      Process Name:  Cap-2900mAh.xml
# 5                                          Equipment             Unit
# 6                                                 67                1
#
#   Unnamed: 2              Unnamed: 3    Unnamed: 4           Unnamed: 5  \
# 0        NaN                     NaN           NaN                  NaN
# 1        NaN                     NaN           NaN                  NaN
# 2        NaN                     NaN           NaN                  NaN
# 3        NaN                     NaN           NaN                  NaN
# 4        NaN                     NaN           NaN                  NaN
# 5    Channel  Battery of Number(P/N)  File of Step           Start time
# 6          1     2020-10-10 20-03-39             -  2020-10-10 20:03:39
#
#             Unnamed: 6    Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                  NaN           NaN        NaN        NaN
# 1                  NaN           NaN        NaN        NaN
# 2                  NaN           NaN        NaN        NaN
# 3                  NaN           NaN        NaN        NaN
# 4                  NaN           NaN        NaN        NaN
# 5             End Time  Grading File      Grade     Remark
# 6  2020-10-16 03:25:39           NaN          0        NaN

# %%
df.to_csv ('detail.csv', index = None, header=True)

# %%
dataset1=pd.read_excel("data_1.xlsx")

# %%
import pandas as pd


df1 = pd.DataFrame(pd.read_excel("data_1.xlsx"))

df1
df1.to_csv ('detailvol.csv', index = None, header=True)

# %% [markdown]
# Create 3 separate '.csv'* files named 'detail.csv', 'detailVol.csv' and 'detailTemp.csv'.
#
# Combine all the data in sheets named like "Detail_67_" only, among the two data files provided, and save into 'detail.csv'
# Combine all the data in sheets named like "DetailVol_67_" only, among the two data files provided, and save into 'detailVol.csv'
# Combine all the data in sheets named like "DetailTemp_67_" only, among the two data files provided, and save into 'detailTemp.csv' Provide attention to the column 'Record Index' which provided index values to avoid mismatching the rows while combining multiple files.

# %%
import pandas


f1 = pandas.read_excel("detail.csv")
f2 = pandas.read_excel("detailvol.csv")


f3 = f1[[]].merge(f2[[]],on = ,how = "left")

f3.to_excel("Detail_67_.xlsx", index = False)
